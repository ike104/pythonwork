# %%
import numpy.random as random

plt.plot(random.normal(size=512))

# %%
noise = random.normal(size=100000)
(_hist,bins,line,)=plt.hist(noise,bins=40)

# %%
print line
noise.std()
# Out:
# [  5.00000000e+00   7.00000000e+00   9.00000000e+00   3.30000000e+01
#    5.90000000e+01   1.05000000e+02   2.01000000e+02   3.22000000e+02
#    5.34000000e+02   9.46000000e+02   1.40700000e+03   2.18700000e+03
#    2.80500000e+03   3.93600000e+03   5.07600000e+03   6.15700000e+03
#    7.18500000e+03   7.96400000e+03   8.36000000e+03   8.64900000e+03
#    8.31300000e+03   7.79900000e+03   6.83600000e+03   5.71600000e+03
#    4.51600000e+03   3.55800000e+03   2.52200000e+03   1.76600000e+03
#    1.16700000e+03   7.82000000e+02   4.70000000e+02   2.88000000e+02
#    1.48000000e+02   9.10000000e+01   4.10000000e+01   2.10000000e+01
#    1.40000000e+01   3.00000000e+00   1.00000000e+00   1.00000000e+00]
# [-4.16128505 -3.94568862 -3.73009219 -3.51449576 -3.29889933 -3.0833029
#  -2.86770646 -2.65211003 -2.4365136  -2.22091717 -2.00532074 -1.7897243
#  -1.57412787 -1.35853144 -1.14293501 -0.92733858 -0.71174214 -0.49614571
#  -0.28054928 -0.06495285  0.15064358  0.36624002  0.58183645  0.79743288
#   1.01302931  1.22862574  1.44422218  1.65981861  1.87541504  2.09101147
#   2.3066079   2.52220434  2.73780077  2.9533972   3.16899363  3.38459006
#   3.6001865   3.81578293  4.03137936  4.24697579  4.46257222]
# <a list of 40 Patch objects>
# 0.99807586082727839

# %%
def gaussian_func(x,x0,peak,sigma):
    return peak*np.exp(-(x-x0)**2/(2*sigma**2))

def err_func(para,x,data):
    calc = gaussian_func(x,para[0],para[1],para[2])
    return calc-data

# %%
import scipy.optimize
x = 0.5*bins[1:] + 0.5*bins[:-1]
para,_ind = scipy.optimize.leastsq(err_func,[0,10000,1],args=(x,_hist))
#noise = random.normal(size=10000)
(_hist,bins,line,) = plt.hist(noise, bins=40)
plt.plot(x, gaussian_func(x, para[0], para[1], para[2]),lw=3)

# %%
print u"中心値", str(para[0])
print u"peak", str(para[1])
print u"標準偏差", str(para[2])
# Out:
# 中心値 0.000768122743038
# peak 8616.64449393
# 標準偏差 1.00231479853
